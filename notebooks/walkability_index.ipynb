# %%
import os

# %%
os.chdir('..')
print(os.getcwd())
# Out:
# /Users/lukebenson/Desktop/UCL/Quant_Methods/qm_final_project

# %%
import geopandas as gpd
import pandas as pd

# %%
gdb_path = "data/WalkabilityIndex/Natl_WI.gdb"

# %%
gpd.list_layers(gdb_path)
# Out:
#                        name geometry_type
# 0  NationalWalkabilityIndex  MultiPolygon

# %%
wi_raw = gpd.read_file(gdb_path, layer='NationalWalkabilityIndex')

# %%
wi_raw.shape
# Out:
# (220739, 30)

# %%
pd.set_option('display.max_columns', None)

# %%
wi_raw.head(10)
# Out:
#         GEOID10       GEOID20 STATEFP COUNTYFP TRACTCE BLKGRPCE  CSA  \
# 0  481130078254  481130078254      48      113  007825        4  206
# 1  481130078252  481130078252      48      113  007825        2  206
# 2  481130078253  481130078253      48      113  007825        3  206
# 3  481130078241  481130078241      48      113  007824        1  206
# 4  481130078242  481130078242      48      113  007824        2  206
# 5  481130078271  481130078271      48      113  007827        1  206
# 6  481130093012  481130093012      48      113  009301        2  206
# 7  481130011022  481130011022      48      113  001102        2  206
# 8  481130114012  481130114012      48      113  011401        2  206
# 9  481130114013  481130114013      48      113  011401        3  206
#
#                    CSA_Name   CBSA                        CBSA_Name  \
# 0  Dallas-Fort Worth, TX-OK  19100  Dallas-Fort Worth-Arlington, TX
# 1  Dallas-Fort Worth, TX-OK  19100  Dallas-Fort Worth-Arlington, TX
# ...

# %%
wi_raw.crs
# Out:
# <Projected CRS: ESRI:102039>
# Name: USA_Contiguous_Albers_Equal_Area_Conic_USGS_version
# Axis Info [cartesian]:
# - [east]: Easting (metre)
# - [north]: Northing (metre)
# Area of Use:
# - undefined
# Coordinate Operation:
# - name: unnamed
# - method: Albers Equal Area
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
wi = wi_raw.to_crs(epsg=4269)

# %%
wi[wi['CSA'] == '206'].plot()
# Out:
# <Axes: >

# %%
wi.loc[1,"geometry"]
# Out:
# <MULTIPOLYGON (((-96.741 32.887, -96.74 32.887, -96.74 32.888, -96.74 32.888...>
